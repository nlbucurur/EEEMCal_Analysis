# %% [markdown]
# # Translation
#
# This code was created with the purpose of translating the data files from the new Shihai software into the format required for the linearity analysis.

# %%
import os
import re
import numpy as np
import pandas as pd
from pathlib import Path

# %%
def decompress_tot(tot_10bit: int) -> int:
    """
    Decompresses 10-bit ToT into approximate 12-bit ToT.
    Keeps values < 512 as is.
    Values >= 512 are decoded as (TOT[8:0] << 3).
    """
    if tot_10bit < 0:
        # If there are invalid values like -1, just pass them through
        return tot_10bit
    if tot_10bit < 512:
        return tot_10bit
    else:
        return (tot_10bit & 0x1FF) << 3  # 0x1FF(0b0111111111) == 511

# %%
def physical_phase(col_index: int, phase_shift: int = 7, n_phases: int = 16) -> int:
    """
    Map column index (0..15) to physical phase with a given shift.
    Example: col=0 -> 7, col=1 -> 8, ..., col=8 -> 15, col=9 -> 0, etc.
    """
    return (phase_shift + col_index) % n_phases

# %%
def extract_dac_from_filename(filename: str) -> int | None:
    m = re.search(r"injdac(\d+)_", filename)
    if m:
        return int(m.group(1))
    return None

# %%
CONFIG = { 
    # Root where you want the output folders
    "base_path": "/home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300", 
    
    # Where the raw folders live
    # "raw_subpath": "format_data/raw_data",
    "raw_subpath": "raw_data",
    
    # "DAC": [100, 200, 300, 400, 450, 600, 750, 800, 850, 925, 1135, 1200, 1345, 1400, 1450, 1550, 1600, 1650, 1765, 1975], 
    "fpga_pb_pairs": [
        # ("208", "008"),
        # ("209", "03"),
        # ("210", "17"),
        ("211", "01")
    ],
    "runs": 1
}

number_of_asic = 2
total_phases = 16
sample_time_interval = 25 # [ns]
phase_time_interval = sample_time_interval / total_phases  # [ns]
phase_shift = 7
mg = 10
ch_injected_in_parallel = 2
# total_injected_channels = 76
total_injected_channels = 16
val = {"ADC": 0, "TOT_10bit": 1, "ToA": 2}

# %%
def get_folders_for_pair(pair_id: int, config=CONFIG):
    base = Path(config["base_path"]) / config["raw_subpath"]
    fpga, pb = config["fpga_pb_pairs"][pair_id]
    injection_dir = base / f"injection_{fpga}"

    if not injection_dir.exists():
        print(f"[WARNING] {injection_dir} not found, skipping this pair_id={pair_id}")
        return []

    folders = []
    for f in injection_dir.iterdir():
        if f.is_dir() and f.name.startswith("205_Injection_"):
            folders.append(f.name)

    return sorted(folders)

# %%
def process_injection_folders(
    folder_names,
    pair_id: int,
    config: dict = CONFIG,
    number_of_asic: int = number_of_asic,
    mg: int = mg,
    ch_injected_in_parallel: int = ch_injected_in_parallel,
    total_injected_channels: int = total_injected_channels,
    val_map: dict = val,
    phase_shift: int = phase_shift
):
    base_path = Path(config["base_path"])               # output root
    raw_base_path = base_path / config["raw_subpath"]   # where raw folders are

    fpga, pb = config["fpga_pb_pairs"][pair_id]

    runs_per_dac: dict[int, int] = {}

    for folder_name in folder_names:
        
        folder_path = raw_base_path / f"injection_{fpga}" / folder_name

        # ---- Find ADC file in this raw folder ----
        adc_pattern = (
            f"205_Injection_asic{number_of_asic}_injdac"
            f"*"
            f"_mg{mg}_pack{ch_injected_in_parallel}_chn{total_injected_channels}_val{val_map['ADC']}.csv"
        )

        adc_files = list(folder_path.glob(adc_pattern))
        if not adc_files:
            print(f"[WARNING] No ADC file found in {folder_path} with pattern {adc_pattern}")
            continue
        if len(adc_files) > 1:
            print(f"[WARNING] More than one ADC file in {folder_path}, using first one: {adc_files[0]}")
        adc_file = adc_files[0]
        
        print(f"[INFO] Processing folder: {folder_path}")
        print(f"       Using ADC file: {adc_file.name}")

        dac = extract_dac_from_filename(adc_file.name)
        if dac is None:
            print(f"[WARNING] Could not extract DAC from filename {adc_file.name}, skipping.")
            continue

        runs_per_dac[dac] = runs_per_dac.get(dac, 0) + 1
        run_index = runs_per_dac[dac]

        tot_file = folder_path / adc_file.name.replace(
            f"_val{val_map['ADC']}.csv", f"_val{val_map['TOT_10bit']}.csv"
        )
        toa_file = folder_path / adc_file.name.replace(
            f"_val{val_map['ADC']}.csv", f"_val{val_map['ToA']}.csv"
        )

        if not tot_file.exists():
            print(f"[WARNING] ToT_10bit file not found: {tot_file}")
            continue
        if not toa_file.exists():
            print(f"[WARNING] ToA file not found: {toa_file}")
            continue

        adc_matrix = np.loadtxt(adc_file, delimiter=",")
        tot10_matrix = np.loadtxt(tot_file, delimiter=",")
        toa_matrix = np.loadtxt(toa_file, delimiter=",")

        if adc_matrix.shape != tot10_matrix.shape or adc_matrix.shape != toa_matrix.shape:
            print(f"[ERROR] Shape mismatch in {folder_path}")
            print(f"  ADC: {adc_matrix.shape}, ToT: {tot10_matrix.shape}, ToA: {toa_matrix.shape}")
            continue

        n_channels, n_cols = adc_matrix.shape

        records = []
        for ch in range(n_channels):
            for col in range(n_cols):
                
                # 🔹 physical phase from column index
                phase = physical_phase(col, phase_shift=phase_shift, n_phases=total_phases)
                
                # 🔹 determine which 25 ns "macro-group" we are in
                mg_i = col // total_phases
                
                # 🔹 phase offset from start phase (7), wrapped to [0, 15]
                delta_phase = (phase - phase_shift) % total_phases
                
                # 🔹 index in time ticks and time in ns
                time_index = delta_phase + mg_i * total_phases
                time = phase_time_interval * time_index  # [ns]
                
                
                adc_val = int(adc_matrix[ch, col])
                tot10_val = int(tot10_matrix[ch, col])
                toa_val = int(toa_matrix[ch, col])
                tot12_val = decompress_tot(tot10_val)

                records.append(
                    {
                        "Channel": ch,
                        "Time": time,
                        "Phase": phase,
                        "ADC": adc_val,
                        "TOT_10bit": tot10_val,
                        "TOT_12bit": tot12_val,
                        "ToA": toa_val,
                    }
                )

        df = pd.DataFrame(
            records,
            columns=["Channel", "Time", "Phase", "ADC", "TOT_10bit", "TOT_12bit", "ToA"]
        )

        # ---- Output path: directly under base_path, in [DAC]DAC ----
        out_dir = base_path / f"data/{dac}dac"
        out_dir.mkdir(parents=True, exist_ok=True)

        out_name = f"inj_adc_samples_{fpga}_pb{pb}_{total_injected_channels}_{dac}_{run_index}.csv"
        out_path = out_dir / out_name

        df.to_csv(out_path, index=False)
        
        print(f"[INFO] Saving output CSV: {out_path}")
        print(f"       (Generated from folder: {folder_name})")
        # print(f"[INFO] Saved {out_path}")
        print("------------------------------------------------------------")

# %%
def process_all_pairs(config=CONFIG):
    n_pairs = len(config["fpga_pb_pairs"])

    for pair_id in range(n_pairs):
        fpga, pb = config["fpga_pb_pairs"][pair_id]
        print(f"\n[INFO] Processing pair_id={pair_id} → FPGA={fpga}, pb={pb}")

        folders = get_folders_for_pair(pair_id, config=config)
        if not folders:
            print(f"[INFO] No folders found for injection_{fpga}, skipping.")
            continue

        process_injection_folders(
            folders,
            pair_id=pair_id,
            config=config
        )

# %%
process_all_pairs()
# Out:
# [INFO] Processing pair_id=0 → FPGA=211, pb=01
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/raw_data/injection_211/205_Injection_20251212_214531
#        Using ADC file: 205_Injection_asic2_injdac0_mg10_pack2_chn16_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/data/0dac/inj_adc_samples_211_pb01_16_0_1.csv
#        (Generated from folder: 205_Injection_20251212_214531)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/raw_data/injection_211/205_Injection_20251212_214640
#        Using ADC file: 205_Injection_asic2_injdac300_mg10_pack2_chn16_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/data/300dac/inj_adc_samples_211_pb01_16_300_1.csv
#        (Generated from folder: 205_Injection_20251212_214640)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/raw_data/injection_211/205_Injection_20251212_214749
#        Using ADC file: 205_Injection_asic2_injdac600_mg10_pack2_chn16_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/data/600dac/inj_adc_samples_211_pb01_16_600_1.csv
#        (Generated from folder: 205_Injection_20251212_214749)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/raw_data/injection_211/205_Injection_20251212_214858
#        Using ADC file: 205_Injection_asic2_injdac900_mg10_pack2_chn16_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/data/900dac/inj_adc_samples_211_pb01_16_900_1.csv
#        (Generated from folder: 205_Injection_20251212_214858)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/raw_data/injection_211/205_Injection_20251212_215005
#        Using ADC file: 205_Injection_asic2_injdac1200_mg10_pack2_chn16_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/data/1200dac/inj_adc_samples_211_pb01_16_1200_1.csv
#        (Generated from folder: 205_Injection_20251212_215005)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/raw_data/injection_211/205_Injection_20251212_215111
#        Using ADC file: 205_Injection_asic2_injdac1500_mg10_pack2_chn16_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/data/1500dac/inj_adc_samples_211_pb01_16_1500_1.csv
#        (Generated from folder: 205_Injection_20251212_215111)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/raw_data/injection_211/205_Injection_20251212_215218
#        Using ADC file: 205_Injection_asic2_injdac1800_mg10_pack2_chn16_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/data/1800dac/inj_adc_samples_211_pb01_16_1800_1.csv
#        (Generated from folder: 205_Injection_20251212_215218)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/raw_data/injection_211/205_Injection_20251212_215325
#        Using ADC file: 205_Injection_asic2_injdac2100_mg10_pack2_chn16_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/data/2100dac/inj_adc_samples_211_pb01_16_2100_1.csv
#        (Generated from folder: 205_Injection_20251212_215325)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/raw_data/injection_211/205_Injection_20251212_215432
#        Using ADC file: 205_Injection_asic2_injdac2400_mg10_pack2_chn16_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/data/2400dac/inj_adc_samples_211_pb01_16_2400_1.csv
#        (Generated from folder: 205_Injection_20251212_215432)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/raw_data/injection_211/205_Injection_20251212_215539
#        Using ADC file: 205_Injection_asic2_injdac2700_mg10_pack2_chn16_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/data/2700dac/inj_adc_samples_211_pb01_16_2700_1.csv
#        (Generated from folder: 205_Injection_20251212_215539)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/raw_data/injection_211/205_Injection_20251212_215646
#        Using ADC file: 205_Injection_asic2_injdac3000_mg10_pack2_chn16_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/data/3000dac/inj_adc_samples_211_pb01_16_3000_1.csv
#        (Generated from folder: 205_Injection_20251212_215646)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/raw_data/injection_211/205_Injection_20251212_215753
#        Using ADC file: 205_Injection_asic2_injdac3300_mg10_pack2_chn16_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/data/3300dac/inj_adc_samples_211_pb01_16_3300_1.csv
#        (Generated from folder: 205_Injection_20251212_215753)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/raw_data/injection_211/205_Injection_20251212_215900
#        Using ADC file: 205_Injection_asic2_injdac3600_mg10_pack2_chn16_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/18_injection_211_example2_ch121_no_filter_Toa100_Tot300/data/3600dac/inj_adc_samples_211_pb01_16_3600_1.csv
#        (Generated from folder: 205_Injection_20251212_215900)
# ------------------------------------------------------------
