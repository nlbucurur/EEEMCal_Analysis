# %% [markdown]
# # Translation
#
# This code was created with the purpose of translating the data files from the new Shihai software into the format required for the linearity analysis.

# %%
import os
import re
import numpy as np
import pandas as pd
from pathlib import Path

# %%
def decompress_tot(tot_10bit: int) -> int:
    """
    Decompresses 10-bit ToT into approximate 12-bit ToT.
    Keeps values < 512 as is.
    Values >= 512 are decoded as (TOT[8:0] << 3).
    """
    if tot_10bit < 0:
        # If there are invalid values like -1, just pass them through
        return tot_10bit
    if tot_10bit < 512:
        return tot_10bit
    else:
        return (tot_10bit & 0x1FF) << 3  # 0x1FF(0b0111111111) == 511

# %%
def physical_phase(col_index: int, phase_shift: int = 7, n_phases: int = 16) -> int:
    """
    Map column index (0..15) to physical phase with a given shift.
    Example: col=0 -> 7, col=1 -> 8, ..., col=8 -> 15, col=9 -> 0, etc.
    """
    return (phase_shift + col_index) % n_phases

# %%
def extract_dac_from_filename(filename: str) -> int | None:
    m = re.search(r"injdac(\d+)_", filename)
    if m:
        return int(m.group(1))
    return None

# %%
CONFIG = { 
    # Root where you want the output folders
    "base_path": "/home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal", 
    
    # Where the raw folders live
    # "raw_subpath": "format_data/raw_data",
    "raw_subpath": "raw_data",
    
    # "DAC": [100, 200, 300, 400, 450, 600, 750, 800, 850, 925, 1135, 1200, 1345, 1400, 1450, 1550, 1600, 1650, 1765, 1975], 
    "fpga_pb_pairs": [
        ("208", "008"),
        # ("209", "03"),
        # ("210", "17"),
        # ("211", "01")
    ],
    "runs": 1
}

number_of_asic = 2
total_phases = 16
sample_time_interval = 25 # [ns]
phase_time_interval = sample_time_interval / total_phases  # [ns]
phase_shift = 7
mg = 10
ch_injected_in_parallel = 2
# total_injected_channels = 76
total_injected_channels = 10
val = {"ADC": 0, "TOT_10bit": 1, "ToA": 2}

# %%
def get_folders_for_pair(pair_id: int, config=CONFIG):
    base = Path(config["base_path"]) / config["raw_subpath"]
    fpga, pb = config["fpga_pb_pairs"][pair_id]
    injection_dir = base / f"injection_{fpga}"

    if not injection_dir.exists():
        print(f"[WARNING] {injection_dir} not found, skipping this pair_id={pair_id}")
        return []

    folders = []
    for f in injection_dir.iterdir():
        if f.is_dir() and f.name.startswith("205_Injection_"):
            folders.append(f.name)

    return sorted(folders)

# %%
def process_injection_folders(
    folder_names,
    pair_id: int,
    config: dict = CONFIG,
    number_of_asic: int = number_of_asic,
    mg: int = mg,
    ch_injected_in_parallel: int = ch_injected_in_parallel,
    total_injected_channels: int = total_injected_channels,
    val_map: dict = val,
    phase_shift: int = phase_shift
):
    base_path = Path(config["base_path"])               # output root
    raw_base_path = base_path / config["raw_subpath"]   # where raw folders are

    fpga, pb = config["fpga_pb_pairs"][pair_id]

    runs_per_dac: dict[int, int] = {}

    for folder_name in folder_names:
        
        folder_path = raw_base_path / f"injection_{fpga}" / folder_name

        # ---- Find ADC file in this raw folder ----
        adc_pattern = (
            f"205_Injection_asic{number_of_asic}_injdac"
            f"*"
            f"_mg{mg}_pack{ch_injected_in_parallel}_chn{total_injected_channels}_val{val_map['ADC']}.csv"
        )

        adc_files = list(folder_path.glob(adc_pattern))
        if not adc_files:
            print(f"[WARNING] No ADC file found in {folder_path} with pattern {adc_pattern}")
            continue
        if len(adc_files) > 1:
            print(f"[WARNING] More than one ADC file in {folder_path}, using first one: {adc_files[0]}")
        adc_file = adc_files[0]
        
        print(f"[INFO] Processing folder: {folder_path}")
        print(f"       Using ADC file: {adc_file.name}")

        dac = extract_dac_from_filename(adc_file.name)
        if dac is None:
            print(f"[WARNING] Could not extract DAC from filename {adc_file.name}, skipping.")
            continue

        runs_per_dac[dac] = runs_per_dac.get(dac, 0) + 1
        run_index = runs_per_dac[dac]

        tot_file = folder_path / adc_file.name.replace(
            f"_val{val_map['ADC']}.csv", f"_val{val_map['TOT_10bit']}.csv"
        )
        toa_file = folder_path / adc_file.name.replace(
            f"_val{val_map['ADC']}.csv", f"_val{val_map['ToA']}.csv"
        )

        if not tot_file.exists():
            print(f"[WARNING] ToT_10bit file not found: {tot_file}")
            continue
        if not toa_file.exists():
            print(f"[WARNING] ToA file not found: {toa_file}")
            continue

        adc_matrix = np.loadtxt(adc_file, delimiter=",")
        tot10_matrix = np.loadtxt(tot_file, delimiter=",")
        toa_matrix = np.loadtxt(toa_file, delimiter=",")

        if adc_matrix.shape != tot10_matrix.shape or adc_matrix.shape != toa_matrix.shape:
            print(f"[ERROR] Shape mismatch in {folder_path}")
            print(f"  ADC: {adc_matrix.shape}, ToT: {tot10_matrix.shape}, ToA: {toa_matrix.shape}")
            continue

        n_channels, n_cols = adc_matrix.shape

        records = []
        for ch in range(n_channels):
            for col in range(n_cols):
                
                # 🔹 physical phase from column index
                phase = physical_phase(col, phase_shift=phase_shift, n_phases=total_phases)
                
                # 🔹 determine which 25 ns "macro-group" we are in
                mg_i = col // total_phases
                
                # 🔹 phase offset from start phase (7), wrapped to [0, 15]
                delta_phase = (phase - phase_shift) % total_phases
                
                # 🔹 index in time ticks and time in ns
                time_index = delta_phase + mg_i * total_phases
                time = phase_time_interval * time_index  # [ns]
                
                
                adc_val = int(adc_matrix[ch, col])
                tot10_val = int(tot10_matrix[ch, col])
                toa_val = int(toa_matrix[ch, col])
                tot12_val = decompress_tot(tot10_val)

                records.append(
                    {
                        "Channel": ch,
                        "Time": time,
                        "Phase": phase,
                        "ADC": adc_val,
                        "TOT_10bit": tot10_val,
                        "TOT_12bit": tot12_val,
                        "ToA": toa_val,
                    }
                )

        df = pd.DataFrame(
            records,
            columns=["Channel", "Time", "Phase", "ADC", "TOT_10bit", "TOT_12bit", "ToA"]
        )

        # ---- Output path: directly under base_path, in [DAC]DAC ----
        out_dir = base_path / f"data/{dac}dac"
        out_dir.mkdir(parents=True, exist_ok=True)

        out_name = f"inj_adc_samples_{fpga}_pb{pb}_{total_injected_channels}_{dac}_{run_index}.csv"
        out_path = out_dir / out_name

        df.to_csv(out_path, index=False)
        
        print(f"[INFO] Saving output CSV: {out_path}")
        print(f"       (Generated from folder: {folder_name})")
        # print(f"[INFO] Saved {out_path}")
        print("------------------------------------------------------------")

# %%
def process_all_pairs(config=CONFIG):
    n_pairs = len(config["fpga_pb_pairs"])

    for pair_id in range(n_pairs):
        fpga, pb = config["fpga_pb_pairs"][pair_id]
        print(f"\n[INFO] Processing pair_id={pair_id} → FPGA={fpga}, pb={pb}")

        folders = get_folders_for_pair(pair_id, config=config)
        if not folders:
            print(f"[INFO] No folders found for injection_{fpga}, skipping.")
            continue

        process_injection_folders(
            folders,
            pair_id=pair_id,
            config=config
        )

# %%
process_all_pairs()
# Out:
# [INFO] Processing pair_id=0 → FPGA=208, pb=008
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_003442
#        Using ADC file: 205_Injection_asic2_injdac100_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/100dac/inj_adc_samples_208_pb008_10_100_1.csv
#        (Generated from folder: 205_Injection_20251212_003442)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_003527
#        Using ADC file: 205_Injection_asic2_injdac150_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/150dac/inj_adc_samples_208_pb008_10_150_1.csv
#        (Generated from folder: 205_Injection_20251212_003527)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_003614
#        Using ADC file: 205_Injection_asic2_injdac200_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/200dac/inj_adc_samples_208_pb008_10_200_1.csv
#        (Generated from folder: 205_Injection_20251212_003614)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_003700
#        Using ADC file: 205_Injection_asic2_injdac250_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/250dac/inj_adc_samples_208_pb008_10_250_1.csv
#        (Generated from folder: 205_Injection_20251212_003700)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_003746
#        Using ADC file: 205_Injection_asic2_injdac300_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/300dac/inj_adc_samples_208_pb008_10_300_1.csv
#        (Generated from folder: 205_Injection_20251212_003746)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_003831
#        Using ADC file: 205_Injection_asic2_injdac350_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/350dac/inj_adc_samples_208_pb008_10_350_1.csv
#        (Generated from folder: 205_Injection_20251212_003831)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_003916
#        Using ADC file: 205_Injection_asic2_injdac400_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/400dac/inj_adc_samples_208_pb008_10_400_1.csv
#        (Generated from folder: 205_Injection_20251212_003916)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004001
#        Using ADC file: 205_Injection_asic2_injdac450_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/450dac/inj_adc_samples_208_pb008_10_450_1.csv
#        (Generated from folder: 205_Injection_20251212_004001)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004047
#        Using ADC file: 205_Injection_asic2_injdac500_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/500dac/inj_adc_samples_208_pb008_10_500_1.csv
#        (Generated from folder: 205_Injection_20251212_004047)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004131
#        Using ADC file: 205_Injection_asic2_injdac550_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/550dac/inj_adc_samples_208_pb008_10_550_1.csv
#        (Generated from folder: 205_Injection_20251212_004131)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004216
#        Using ADC file: 205_Injection_asic2_injdac600_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/600dac/inj_adc_samples_208_pb008_10_600_1.csv
#        (Generated from folder: 205_Injection_20251212_004216)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004301
#        Using ADC file: 205_Injection_asic2_injdac650_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/650dac/inj_adc_samples_208_pb008_10_650_1.csv
#        (Generated from folder: 205_Injection_20251212_004301)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004346
#        Using ADC file: 205_Injection_asic2_injdac700_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/700dac/inj_adc_samples_208_pb008_10_700_1.csv
#        (Generated from folder: 205_Injection_20251212_004346)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004432
#        Using ADC file: 205_Injection_asic2_injdac750_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/750dac/inj_adc_samples_208_pb008_10_750_1.csv
#        (Generated from folder: 205_Injection_20251212_004432)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004518
#        Using ADC file: 205_Injection_asic2_injdac800_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/800dac/inj_adc_samples_208_pb008_10_800_1.csv
#        (Generated from folder: 205_Injection_20251212_004518)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004603
#        Using ADC file: 205_Injection_asic2_injdac850_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/850dac/inj_adc_samples_208_pb008_10_850_1.csv
#        (Generated from folder: 205_Injection_20251212_004603)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004648
#        Using ADC file: 205_Injection_asic2_injdac900_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/900dac/inj_adc_samples_208_pb008_10_900_1.csv
#        (Generated from folder: 205_Injection_20251212_004648)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004733
#        Using ADC file: 205_Injection_asic2_injdac950_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/950dac/inj_adc_samples_208_pb008_10_950_1.csv
#        (Generated from folder: 205_Injection_20251212_004733)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004819
#        Using ADC file: 205_Injection_asic2_injdac1000_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1000dac/inj_adc_samples_208_pb008_10_1000_1.csv
#        (Generated from folder: 205_Injection_20251212_004819)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004904
#        Using ADC file: 205_Injection_asic2_injdac1050_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1050dac/inj_adc_samples_208_pb008_10_1050_1.csv
#        (Generated from folder: 205_Injection_20251212_004904)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_004949
#        Using ADC file: 205_Injection_asic2_injdac1100_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1100dac/inj_adc_samples_208_pb008_10_1100_1.csv
#        (Generated from folder: 205_Injection_20251212_004949)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_005034
#        Using ADC file: 205_Injection_asic2_injdac1150_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1150dac/inj_adc_samples_208_pb008_10_1150_1.csv
#        (Generated from folder: 205_Injection_20251212_005034)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_005119
#        Using ADC file: 205_Injection_asic2_injdac1200_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1200dac/inj_adc_samples_208_pb008_10_1200_1.csv
#        (Generated from folder: 205_Injection_20251212_005119)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_005204
#        Using ADC file: 205_Injection_asic2_injdac1250_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1250dac/inj_adc_samples_208_pb008_10_1250_1.csv
#        (Generated from folder: 205_Injection_20251212_005204)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_005249
#        Using ADC file: 205_Injection_asic2_injdac1300_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1300dac/inj_adc_samples_208_pb008_10_1300_1.csv
#        (Generated from folder: 205_Injection_20251212_005249)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_005334
#        Using ADC file: 205_Injection_asic2_injdac1350_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1350dac/inj_adc_samples_208_pb008_10_1350_1.csv
#        (Generated from folder: 205_Injection_20251212_005334)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_005420
#        Using ADC file: 205_Injection_asic2_injdac1400_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1400dac/inj_adc_samples_208_pb008_10_1400_1.csv
#        (Generated from folder: 205_Injection_20251212_005420)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_005505
#        Using ADC file: 205_Injection_asic2_injdac1450_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1450dac/inj_adc_samples_208_pb008_10_1450_1.csv
#        (Generated from folder: 205_Injection_20251212_005505)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_005550
#        Using ADC file: 205_Injection_asic2_injdac1500_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1500dac/inj_adc_samples_208_pb008_10_1500_1.csv
#        (Generated from folder: 205_Injection_20251212_005550)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_005635
#        Using ADC file: 205_Injection_asic2_injdac1550_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1550dac/inj_adc_samples_208_pb008_10_1550_1.csv
#        (Generated from folder: 205_Injection_20251212_005635)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_005721
#        Using ADC file: 205_Injection_asic2_injdac1600_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1600dac/inj_adc_samples_208_pb008_10_1600_1.csv
#        (Generated from folder: 205_Injection_20251212_005721)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_005807
#        Using ADC file: 205_Injection_asic2_injdac1650_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1650dac/inj_adc_samples_208_pb008_10_1650_1.csv
#        (Generated from folder: 205_Injection_20251212_005807)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_005854
#        Using ADC file: 205_Injection_asic2_injdac1700_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1700dac/inj_adc_samples_208_pb008_10_1700_1.csv
#        (Generated from folder: 205_Injection_20251212_005854)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_005939
#        Using ADC file: 205_Injection_asic2_injdac1750_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1750dac/inj_adc_samples_208_pb008_10_1750_1.csv
#        (Generated from folder: 205_Injection_20251212_005939)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_010023
#        Using ADC file: 205_Injection_asic2_injdac1800_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1800dac/inj_adc_samples_208_pb008_10_1800_1.csv
#        (Generated from folder: 205_Injection_20251212_010023)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_010108
#        Using ADC file: 205_Injection_asic2_injdac1850_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1850dac/inj_adc_samples_208_pb008_10_1850_1.csv
#        (Generated from folder: 205_Injection_20251212_010108)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_010153
#        Using ADC file: 205_Injection_asic2_injdac1900_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1900dac/inj_adc_samples_208_pb008_10_1900_1.csv
#        (Generated from folder: 205_Injection_20251212_010153)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_010237
#        Using ADC file: 205_Injection_asic2_injdac1950_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/1950dac/inj_adc_samples_208_pb008_10_1950_1.csv
#        (Generated from folder: 205_Injection_20251212_010237)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_010322
#        Using ADC file: 205_Injection_asic2_injdac2000_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2000dac/inj_adc_samples_208_pb008_10_2000_1.csv
#        (Generated from folder: 205_Injection_20251212_010322)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_010407
#        Using ADC file: 205_Injection_asic2_injdac2050_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2050dac/inj_adc_samples_208_pb008_10_2050_1.csv
#        (Generated from folder: 205_Injection_20251212_010407)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_010452
#        Using ADC file: 205_Injection_asic2_injdac2100_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2100dac/inj_adc_samples_208_pb008_10_2100_1.csv
#        (Generated from folder: 205_Injection_20251212_010452)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_010537
#        Using ADC file: 205_Injection_asic2_injdac2150_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2150dac/inj_adc_samples_208_pb008_10_2150_1.csv
#        (Generated from folder: 205_Injection_20251212_010537)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_010623
#        Using ADC file: 205_Injection_asic2_injdac2200_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2200dac/inj_adc_samples_208_pb008_10_2200_1.csv
#        (Generated from folder: 205_Injection_20251212_010623)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_010709
#        Using ADC file: 205_Injection_asic2_injdac2250_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2250dac/inj_adc_samples_208_pb008_10_2250_1.csv
#        (Generated from folder: 205_Injection_20251212_010709)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_010754
#        Using ADC file: 205_Injection_asic2_injdac2300_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2300dac/inj_adc_samples_208_pb008_10_2300_1.csv
#        (Generated from folder: 205_Injection_20251212_010754)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_010840
#        Using ADC file: 205_Injection_asic2_injdac2350_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2350dac/inj_adc_samples_208_pb008_10_2350_1.csv
#        (Generated from folder: 205_Injection_20251212_010840)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_010927
#        Using ADC file: 205_Injection_asic2_injdac2400_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2400dac/inj_adc_samples_208_pb008_10_2400_1.csv
#        (Generated from folder: 205_Injection_20251212_010927)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_011012
#        Using ADC file: 205_Injection_asic2_injdac2450_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2450dac/inj_adc_samples_208_pb008_10_2450_1.csv
#        (Generated from folder: 205_Injection_20251212_011012)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_011057
#        Using ADC file: 205_Injection_asic2_injdac2500_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2500dac/inj_adc_samples_208_pb008_10_2500_1.csv
#        (Generated from folder: 205_Injection_20251212_011057)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_011143
#        Using ADC file: 205_Injection_asic2_injdac2550_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2550dac/inj_adc_samples_208_pb008_10_2550_1.csv
#        (Generated from folder: 205_Injection_20251212_011143)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_011228
#        Using ADC file: 205_Injection_asic2_injdac2600_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2600dac/inj_adc_samples_208_pb008_10_2600_1.csv
#        (Generated from folder: 205_Injection_20251212_011228)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_011313
#        Using ADC file: 205_Injection_asic2_injdac2650_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2650dac/inj_adc_samples_208_pb008_10_2650_1.csv
#        (Generated from folder: 205_Injection_20251212_011313)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_011359
#        Using ADC file: 205_Injection_asic2_injdac2700_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2700dac/inj_adc_samples_208_pb008_10_2700_1.csv
#        (Generated from folder: 205_Injection_20251212_011359)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_011444
#        Using ADC file: 205_Injection_asic2_injdac2750_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2750dac/inj_adc_samples_208_pb008_10_2750_1.csv
#        (Generated from folder: 205_Injection_20251212_011444)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_011529
#        Using ADC file: 205_Injection_asic2_injdac2800_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2800dac/inj_adc_samples_208_pb008_10_2800_1.csv
#        (Generated from folder: 205_Injection_20251212_011529)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_011615
#        Using ADC file: 205_Injection_asic2_injdac2850_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2850dac/inj_adc_samples_208_pb008_10_2850_1.csv
#        (Generated from folder: 205_Injection_20251212_011615)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_011659
#        Using ADC file: 205_Injection_asic2_injdac2900_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2900dac/inj_adc_samples_208_pb008_10_2900_1.csv
#        (Generated from folder: 205_Injection_20251212_011659)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_011744
#        Using ADC file: 205_Injection_asic2_injdac2950_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/2950dac/inj_adc_samples_208_pb008_10_2950_1.csv
#        (Generated from folder: 205_Injection_20251212_011744)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_011830
#        Using ADC file: 205_Injection_asic2_injdac3000_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3000dac/inj_adc_samples_208_pb008_10_3000_1.csv
#        (Generated from folder: 205_Injection_20251212_011830)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_011915
#        Using ADC file: 205_Injection_asic2_injdac3050_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3050dac/inj_adc_samples_208_pb008_10_3050_1.csv
#        (Generated from folder: 205_Injection_20251212_011915)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012000
#        Using ADC file: 205_Injection_asic2_injdac3100_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3100dac/inj_adc_samples_208_pb008_10_3100_1.csv
#        (Generated from folder: 205_Injection_20251212_012000)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012044
#        Using ADC file: 205_Injection_asic2_injdac3150_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3150dac/inj_adc_samples_208_pb008_10_3150_1.csv
#        (Generated from folder: 205_Injection_20251212_012044)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012129
#        Using ADC file: 205_Injection_asic2_injdac3200_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3200dac/inj_adc_samples_208_pb008_10_3200_1.csv
#        (Generated from folder: 205_Injection_20251212_012129)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012214
#        Using ADC file: 205_Injection_asic2_injdac3250_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3250dac/inj_adc_samples_208_pb008_10_3250_1.csv
#        (Generated from folder: 205_Injection_20251212_012214)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012259
#        Using ADC file: 205_Injection_asic2_injdac3300_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3300dac/inj_adc_samples_208_pb008_10_3300_1.csv
#        (Generated from folder: 205_Injection_20251212_012259)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012343
#        Using ADC file: 205_Injection_asic2_injdac3350_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3350dac/inj_adc_samples_208_pb008_10_3350_1.csv
#        (Generated from folder: 205_Injection_20251212_012343)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012429
#        Using ADC file: 205_Injection_asic2_injdac3400_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3400dac/inj_adc_samples_208_pb008_10_3400_1.csv
#        (Generated from folder: 205_Injection_20251212_012429)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012514
#        Using ADC file: 205_Injection_asic2_injdac3450_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3450dac/inj_adc_samples_208_pb008_10_3450_1.csv
#        (Generated from folder: 205_Injection_20251212_012514)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012559
#        Using ADC file: 205_Injection_asic2_injdac3500_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3500dac/inj_adc_samples_208_pb008_10_3500_1.csv
#        (Generated from folder: 205_Injection_20251212_012559)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012644
#        Using ADC file: 205_Injection_asic2_injdac3550_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3550dac/inj_adc_samples_208_pb008_10_3550_1.csv
#        (Generated from folder: 205_Injection_20251212_012644)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012729
#        Using ADC file: 205_Injection_asic2_injdac3600_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3600dac/inj_adc_samples_208_pb008_10_3600_1.csv
#        (Generated from folder: 205_Injection_20251212_012729)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012814
#        Using ADC file: 205_Injection_asic2_injdac3650_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3650dac/inj_adc_samples_208_pb008_10_3650_1.csv
#        (Generated from folder: 205_Injection_20251212_012814)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012859
#        Using ADC file: 205_Injection_asic2_injdac3700_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3700dac/inj_adc_samples_208_pb008_10_3700_1.csv
#        (Generated from folder: 205_Injection_20251212_012859)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_012944
#        Using ADC file: 205_Injection_asic2_injdac3750_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3750dac/inj_adc_samples_208_pb008_10_3750_1.csv
#        (Generated from folder: 205_Injection_20251212_012944)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_013028
#        Using ADC file: 205_Injection_asic2_injdac3800_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3800dac/inj_adc_samples_208_pb008_10_3800_1.csv
#        (Generated from folder: 205_Injection_20251212_013028)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_013113
#        Using ADC file: 205_Injection_asic2_injdac3850_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3850dac/inj_adc_samples_208_pb008_10_3850_1.csv
#        (Generated from folder: 205_Injection_20251212_013113)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_013158
#        Using ADC file: 205_Injection_asic2_injdac3900_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3900dac/inj_adc_samples_208_pb008_10_3900_1.csv
#        (Generated from folder: 205_Injection_20251212_013158)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/raw_data/injection_208/205_Injection_20251212_013243
#        Using ADC file: 205_Injection_asic2_injdac3950_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/14_injection_208_example2_ch80_no_new_pedestal/data/3950dac/inj_adc_samples_208_pb008_10_3950_1.csv
#        (Generated from folder: 205_Injection_20251212_013243)
# ------------------------------------------------------------
