# %% [markdown]
# # Translation
#
# This code was created with the purpose of translating the data files from the new Shihai software into the format required for the linearity analysis.

# %%
import os
import re
import numpy as np
import pandas as pd
from pathlib import Path

# %%
def decompress_tot(tot_10bit: int) -> int:
    """
    Decompresses 10-bit ToT into approximate 12-bit ToT.
    Keeps values < 512 as is.
    Values >= 512 are decoded as (TOT[8:0] << 3).
    """
    if tot_10bit < 0:
        # If there are invalid values like -1, just pass them through
        return tot_10bit
    if tot_10bit < 512:
        return tot_10bit
    else:
        return (tot_10bit & 0x1FF) << 3  # 0x1FF(0b0111111111) == 511

# %%
def physical_phase(col_index: int, phase_shift: int = 7, n_phases: int = 16) -> int:
    """
    Map column index (0..15) to physical phase with a given shift.
    Example: col=0 -> 7, col=1 -> 8, ..., col=8 -> 15, col=9 -> 0, etc.
    """
    return (phase_shift + col_index) % n_phases

# %%
def extract_dac_from_filename(filename: str) -> int | None:
    m = re.search(r"injdac(\d+)_", filename)
    if m:
        return int(m.group(1))
    return None

# %%
CONFIG = { 
    # Root where you want the output folders
    "base_path": "/home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300", 
    
    # Where the raw folders live
    # "raw_subpath": "format_data/raw_data",
    "raw_subpath": "raw_data",
    
    # "DAC": [100, 200, 300, 400, 450, 600, 750, 800, 850, 925, 1135, 1200, 1345, 1400, 1450, 1550, 1600, 1650, 1765, 1975], 
    "fpga_pb_pairs": [
        ("208", "008"),
        # ("209", "03"),
        # ("210", "17"),
        # ("211", "01")
    ],
    "runs": 1
}

number_of_asic = 2
total_phases = 16
sample_time_interval = 25 # [ns]
phase_time_interval = sample_time_interval / total_phases  # [ns]
phase_shift = 7
mg = 10
ch_injected_in_parallel = 2
# total_injected_channels = 76
total_injected_channels = 10
val = {"ADC": 0, "TOT_10bit": 1, "ToA": 2}

# %%
def get_folders_for_pair(pair_id: int, config=CONFIG):
    base = Path(config["base_path"]) / config["raw_subpath"]
    fpga, pb = config["fpga_pb_pairs"][pair_id]
    injection_dir = base / f"injection_{fpga}"

    if not injection_dir.exists():
        print(f"[WARNING] {injection_dir} not found, skipping this pair_id={pair_id}")
        return []

    folders = []
    for f in injection_dir.iterdir():
        if f.is_dir() and f.name.startswith("205_Injection_"):
            folders.append(f.name)

    return sorted(folders)

# %%
def process_injection_folders(
    folder_names,
    pair_id: int,
    config: dict = CONFIG,
    number_of_asic: int = number_of_asic,
    mg: int = mg,
    ch_injected_in_parallel: int = ch_injected_in_parallel,
    total_injected_channels: int = total_injected_channels,
    val_map: dict = val,
    phase_shift: int = phase_shift
):
    base_path = Path(config["base_path"])               # output root
    raw_base_path = base_path / config["raw_subpath"]   # where raw folders are

    fpga, pb = config["fpga_pb_pairs"][pair_id]

    runs_per_dac: dict[int, int] = {}

    for folder_name in folder_names:
        
        folder_path = raw_base_path / f"injection_{fpga}" / folder_name

        # ---- Find ADC file in this raw folder ----
        adc_pattern = (
            f"205_Injection_asic{number_of_asic}_injdac"
            f"*"
            f"_mg{mg}_pack{ch_injected_in_parallel}_chn{total_injected_channels}_val{val_map['ADC']}.csv"
        )

        adc_files = list(folder_path.glob(adc_pattern))
        if not adc_files:
            print(f"[WARNING] No ADC file found in {folder_path} with pattern {adc_pattern}")
            continue
        if len(adc_files) > 1:
            print(f"[WARNING] More than one ADC file in {folder_path}, using first one: {adc_files[0]}")
        adc_file = adc_files[0]
        
        print(f"[INFO] Processing folder: {folder_path}")
        print(f"       Using ADC file: {adc_file.name}")

        dac = extract_dac_from_filename(adc_file.name)
        if dac is None:
            print(f"[WARNING] Could not extract DAC from filename {adc_file.name}, skipping.")
            continue

        runs_per_dac[dac] = runs_per_dac.get(dac, 0) + 1
        run_index = runs_per_dac[dac]

        tot_file = folder_path / adc_file.name.replace(
            f"_val{val_map['ADC']}.csv", f"_val{val_map['TOT_10bit']}.csv"
        )
        toa_file = folder_path / adc_file.name.replace(
            f"_val{val_map['ADC']}.csv", f"_val{val_map['ToA']}.csv"
        )

        if not tot_file.exists():
            print(f"[WARNING] ToT_10bit file not found: {tot_file}")
            continue
        if not toa_file.exists():
            print(f"[WARNING] ToA file not found: {toa_file}")
            continue

        adc_matrix = np.loadtxt(adc_file, delimiter=",")
        tot10_matrix = np.loadtxt(tot_file, delimiter=",")
        toa_matrix = np.loadtxt(toa_file, delimiter=",")

        if adc_matrix.shape != tot10_matrix.shape or adc_matrix.shape != toa_matrix.shape:
            print(f"[ERROR] Shape mismatch in {folder_path}")
            print(f"  ADC: {adc_matrix.shape}, ToT: {tot10_matrix.shape}, ToA: {toa_matrix.shape}")
            continue

        n_channels, n_cols = adc_matrix.shape

        records = []
        for ch in range(n_channels):
            for col in range(n_cols):
                
                # 🔹 physical phase from column index
                phase = physical_phase(col, phase_shift=phase_shift, n_phases=total_phases)
                
                # 🔹 determine which 25 ns "macro-group" we are in
                mg_i = col // total_phases
                
                # 🔹 phase offset from start phase (7), wrapped to [0, 15]
                delta_phase = (phase - phase_shift) % total_phases
                
                # 🔹 index in time ticks and time in ns
                time_index = delta_phase + mg_i * total_phases
                time = phase_time_interval * time_index  # [ns]
                
                
                adc_val = int(adc_matrix[ch, col])
                tot10_val = int(tot10_matrix[ch, col])
                toa_val = int(toa_matrix[ch, col])
                tot12_val = decompress_tot(tot10_val)

                records.append(
                    {
                        "Channel": ch,
                        "Time": time,
                        "Phase": phase,
                        "ADC": adc_val,
                        "TOT_10bit": tot10_val,
                        "TOT_12bit": tot12_val,
                        "ToA": toa_val,
                    }
                )

        df = pd.DataFrame(
            records,
            columns=["Channel", "Time", "Phase", "ADC", "TOT_10bit", "TOT_12bit", "ToA"]
        )

        # ---- Output path: directly under base_path, in [DAC]DAC ----
        out_dir = base_path / f"data/{dac}dac"
        out_dir.mkdir(parents=True, exist_ok=True)

        out_name = f"inj_adc_samples_{fpga}_pb{pb}_{total_injected_channels}_{dac}_{run_index}.csv"
        out_path = out_dir / out_name

        df.to_csv(out_path, index=False)
        
        print(f"[INFO] Saving output CSV: {out_path}")
        print(f"       (Generated from folder: {folder_name})")
        # print(f"[INFO] Saved {out_path}")
        print("------------------------------------------------------------")

# %%
def process_all_pairs(config=CONFIG):
    n_pairs = len(config["fpga_pb_pairs"])

    for pair_id in range(n_pairs):
        fpga, pb = config["fpga_pb_pairs"][pair_id]
        print(f"\n[INFO] Processing pair_id={pair_id} → FPGA={fpga}, pb={pb}")

        folders = get_folders_for_pair(pair_id, config=config)
        if not folders:
            print(f"[INFO] No folders found for injection_{fpga}, skipping.")
            continue

        process_injection_folders(
            folders,
            pair_id=pair_id,
            config=config
        )

# %%
process_all_pairs()
# Out:
# [INFO] Processing pair_id=0 → FPGA=208, pb=008
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_154523
#        Using ADC file: 205_Injection_asic2_injdac100_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/100dac/inj_adc_samples_208_pb008_10_100_1.csv
#        (Generated from folder: 205_Injection_20251212_154523)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_154609
#        Using ADC file: 205_Injection_asic2_injdac200_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/200dac/inj_adc_samples_208_pb008_10_200_1.csv
#        (Generated from folder: 205_Injection_20251212_154609)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_154655
#        Using ADC file: 205_Injection_asic2_injdac300_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/300dac/inj_adc_samples_208_pb008_10_300_1.csv
#        (Generated from folder: 205_Injection_20251212_154655)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_154741
#        Using ADC file: 205_Injection_asic2_injdac400_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/400dac/inj_adc_samples_208_pb008_10_400_1.csv
#        (Generated from folder: 205_Injection_20251212_154741)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_154826
#        Using ADC file: 205_Injection_asic2_injdac500_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/500dac/inj_adc_samples_208_pb008_10_500_1.csv
#        (Generated from folder: 205_Injection_20251212_154826)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_154912
#        Using ADC file: 205_Injection_asic2_injdac600_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/600dac/inj_adc_samples_208_pb008_10_600_1.csv
#        (Generated from folder: 205_Injection_20251212_154912)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_154958
#        Using ADC file: 205_Injection_asic2_injdac700_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/700dac/inj_adc_samples_208_pb008_10_700_1.csv
#        (Generated from folder: 205_Injection_20251212_154958)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_155043
#        Using ADC file: 205_Injection_asic2_injdac800_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/800dac/inj_adc_samples_208_pb008_10_800_1.csv
#        (Generated from folder: 205_Injection_20251212_155043)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_155130
#        Using ADC file: 205_Injection_asic2_injdac900_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/900dac/inj_adc_samples_208_pb008_10_900_1.csv
#        (Generated from folder: 205_Injection_20251212_155130)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_155217
#        Using ADC file: 205_Injection_asic2_injdac1000_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/1000dac/inj_adc_samples_208_pb008_10_1000_1.csv
#        (Generated from folder: 205_Injection_20251212_155217)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_155302
#        Using ADC file: 205_Injection_asic2_injdac1100_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/1100dac/inj_adc_samples_208_pb008_10_1100_1.csv
#        (Generated from folder: 205_Injection_20251212_155302)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_155350
#        Using ADC file: 205_Injection_asic2_injdac1200_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/1200dac/inj_adc_samples_208_pb008_10_1200_1.csv
#        (Generated from folder: 205_Injection_20251212_155350)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_155436
#        Using ADC file: 205_Injection_asic2_injdac1300_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/1300dac/inj_adc_samples_208_pb008_10_1300_1.csv
#        (Generated from folder: 205_Injection_20251212_155436)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_155523
#        Using ADC file: 205_Injection_asic2_injdac1400_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/1400dac/inj_adc_samples_208_pb008_10_1400_1.csv
#        (Generated from folder: 205_Injection_20251212_155523)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_155609
#        Using ADC file: 205_Injection_asic2_injdac1500_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/1500dac/inj_adc_samples_208_pb008_10_1500_1.csv
#        (Generated from folder: 205_Injection_20251212_155609)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_155654
#        Using ADC file: 205_Injection_asic2_injdac1600_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/1600dac/inj_adc_samples_208_pb008_10_1600_1.csv
#        (Generated from folder: 205_Injection_20251212_155654)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_155740
#        Using ADC file: 205_Injection_asic2_injdac1700_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/1700dac/inj_adc_samples_208_pb008_10_1700_1.csv
#        (Generated from folder: 205_Injection_20251212_155740)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_155825
#        Using ADC file: 205_Injection_asic2_injdac1800_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/1800dac/inj_adc_samples_208_pb008_10_1800_1.csv
#        (Generated from folder: 205_Injection_20251212_155825)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_155909
#        Using ADC file: 205_Injection_asic2_injdac1900_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/1900dac/inj_adc_samples_208_pb008_10_1900_1.csv
#        (Generated from folder: 205_Injection_20251212_155909)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_155954
#        Using ADC file: 205_Injection_asic2_injdac2000_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/2000dac/inj_adc_samples_208_pb008_10_2000_1.csv
#        (Generated from folder: 205_Injection_20251212_155954)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_160039
#        Using ADC file: 205_Injection_asic2_injdac2100_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/2100dac/inj_adc_samples_208_pb008_10_2100_1.csv
#        (Generated from folder: 205_Injection_20251212_160039)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_160124
#        Using ADC file: 205_Injection_asic2_injdac2200_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/2200dac/inj_adc_samples_208_pb008_10_2200_1.csv
#        (Generated from folder: 205_Injection_20251212_160124)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_160208
#        Using ADC file: 205_Injection_asic2_injdac2300_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/2300dac/inj_adc_samples_208_pb008_10_2300_1.csv
#        (Generated from folder: 205_Injection_20251212_160208)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_160254
#        Using ADC file: 205_Injection_asic2_injdac2400_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/2400dac/inj_adc_samples_208_pb008_10_2400_1.csv
#        (Generated from folder: 205_Injection_20251212_160254)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_160340
#        Using ADC file: 205_Injection_asic2_injdac2500_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/2500dac/inj_adc_samples_208_pb008_10_2500_1.csv
#        (Generated from folder: 205_Injection_20251212_160340)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_160427
#        Using ADC file: 205_Injection_asic2_injdac2600_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/2600dac/inj_adc_samples_208_pb008_10_2600_1.csv
#        (Generated from folder: 205_Injection_20251212_160427)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_160513
#        Using ADC file: 205_Injection_asic2_injdac2700_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/2700dac/inj_adc_samples_208_pb008_10_2700_1.csv
#        (Generated from folder: 205_Injection_20251212_160513)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_160558
#        Using ADC file: 205_Injection_asic2_injdac2800_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/2800dac/inj_adc_samples_208_pb008_10_2800_1.csv
#        (Generated from folder: 205_Injection_20251212_160558)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_160643
#        Using ADC file: 205_Injection_asic2_injdac2900_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/2900dac/inj_adc_samples_208_pb008_10_2900_1.csv
#        (Generated from folder: 205_Injection_20251212_160643)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_160728
#        Using ADC file: 205_Injection_asic2_injdac3000_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/3000dac/inj_adc_samples_208_pb008_10_3000_1.csv
#        (Generated from folder: 205_Injection_20251212_160728)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_160813
#        Using ADC file: 205_Injection_asic2_injdac3100_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/3100dac/inj_adc_samples_208_pb008_10_3100_1.csv
#        (Generated from folder: 205_Injection_20251212_160813)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_160857
#        Using ADC file: 205_Injection_asic2_injdac3200_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/3200dac/inj_adc_samples_208_pb008_10_3200_1.csv
#        (Generated from folder: 205_Injection_20251212_160857)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_160942
#        Using ADC file: 205_Injection_asic2_injdac3300_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/3300dac/inj_adc_samples_208_pb008_10_3300_1.csv
#        (Generated from folder: 205_Injection_20251212_160942)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_161028
#        Using ADC file: 205_Injection_asic2_injdac3400_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/3400dac/inj_adc_samples_208_pb008_10_3400_1.csv
#        (Generated from folder: 205_Injection_20251212_161028)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_161113
#        Using ADC file: 205_Injection_asic2_injdac3500_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/3500dac/inj_adc_samples_208_pb008_10_3500_1.csv
#        (Generated from folder: 205_Injection_20251212_161113)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_161158
#        Using ADC file: 205_Injection_asic2_injdac3600_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/3600dac/inj_adc_samples_208_pb008_10_3600_1.csv
#        (Generated from folder: 205_Injection_20251212_161158)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_161243
#        Using ADC file: 205_Injection_asic2_injdac3700_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/3700dac/inj_adc_samples_208_pb008_10_3700_1.csv
#        (Generated from folder: 205_Injection_20251212_161243)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_161330
#        Using ADC file: 205_Injection_asic2_injdac3800_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/3800dac/inj_adc_samples_208_pb008_10_3800_1.csv
#        (Generated from folder: 205_Injection_20251212_161330)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_161415
#        Using ADC file: 205_Injection_asic2_injdac3900_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/3900dac/inj_adc_samples_208_pb008_10_3900_1.csv
#        (Generated from folder: 205_Injection_20251212_161415)
# ------------------------------------------------------------
# [INFO] Processing folder: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/raw_data/injection_208/205_Injection_20251212_161501
#        Using ADC file: 205_Injection_asic2_injdac4000_mg10_pack2_chn10_val0.csv
# [INFO] Saving output CSV: /home/lorena/Documents/PhD/EEEMCal_Analysis/DESY_Internal_Injection/15_injection_208_example2_ch80_Toa300/data/4000dac/inj_adc_samples_208_pb008_10_4000_1.csv
#        (Generated from folder: 205_Injection_20251212_161501)
# ------------------------------------------------------------
