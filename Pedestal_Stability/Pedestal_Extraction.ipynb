# %% [markdown]
# ### Build the CSV of pedestal values (HV & NoHV) for FPGA 209 (PB 008) and FPGA 210 (PB 06)

# %%
import json
from pathlib import Path
import pandas as pd

# %%
base = Path("/home/lorena/Documents/PhD/EEEMCal_Analysis/Pedestal_Stability/Data/Pedestals")
files = {
    ("209", "008", "NoHV"): base / "103_PedestalCalib_pedecalib_20251017_132119.json",
    # ("209", "008", "NoHV"): base / "103_PedestalCalib_pedecalib_20251017_174324.json",
    ("209", "008", "HV"):   base / "103_PedestalCalib_pedecalib_20251017_174324.json",
    # ("209", "008", "HV"):   base / "103_PedestalCalib_pedecalib_20251017_132119.json",
    ("210", "06",  "NoHV"): base / "103_PedestalCalib_pedecalib_20251017_132121.json",
    ("210", "06",  "HV"):   base / "103_PedestalCalib_pedecalib_20251017_174322.json",
}

# %%
# Channels to exclude completely (1-based indexing)
exclude_channels = {19, 38, 57, 76, 95, 114, 133}

# Helper: load pede_values into a dict {channel_number: pedestal}
def load_pedestals(json_path):
    with open(json_path, "r") as f:
        data = json.load(f)
    pede_values = data.get("pede_values", [])
    # Build 1..151 mapping (skip channel 0, and ignore >151 if present)
    mapping = {ch: pede_values[ch] for ch in range(1, min(len(pede_values), 152)) if ch not in exclude_channels}
    return mapping

# %%
# Build long dataframe: one row per (FPGA, PB, Channel, Condition, Pedestal)
rows = []
for (fpga, pb, cond), path in files.items():
    ped = load_pedestals(path)
    for ch, val in ped.items():
        rows.append({
            "FPGA": fpga,
            "PB": pb,
            "Channel": ch,
            "Condition": cond,
            "Pedestal": val
        })

df_long = pd.DataFrame(rows).sort_values(["FPGA", "PB", "Channel", "Condition"]).reset_index(drop=True)

# %%
# Pivot to get HV and NoHV columns side-by-side per FPGA/PB/Channel
df_wide = df_long.pivot_table(index=["FPGA", "PB", "Channel"], columns="Condition", values="Pedestal").reset_index()
# Ensure column order
if "HV" not in df_wide.columns: df_wide["HV"] = pd.NA
if "NoHV" not in df_wide.columns: df_wide["NoHV"] = pd.NA
df_wide = df_wide[["FPGA", "PB", "Channel", "NoHV", "HV"]].sort_values(["FPGA", "PB", "Channel"]).reset_index(drop=True)

# %%
# Save CSV
out_csv = base / "pedestals_HV_vs_NoHV_FPGA209_210.csv"
df_wide.to_csv(out_csv, index=False)

# %%
# Show first 20 rows in Jupyter
display(df_wide.head(20))

# Print output file path
print(f"✅ CSV saved to: {out_csv}")
# Out:
# Condition FPGA   PB  Channel   NoHV     HV
# 0          209  008        1  101.0   81.0
# 1          209  008        2   96.0   79.0
# 2          209  008        3   95.0   79.0
# 3          209  008        4   95.0   78.0
# 4          209  008        5   97.0   81.0
# 5          209  008        6   95.0   79.0
# 6          209  008        7   95.0   81.0
# 7          209  008        8   95.0   79.0
# 8          209  008        9  115.0  118.0
# 9          209  008       10   94.0   81.0
# 10         209  008       11  107.0   95.0
# 11         209  008       12  102.0   87.0
# 12         209  008       13   94.0   78.0
# 13         209  008       14   97.0   81.0
# 14         209  008       15   93.0   80.0
# 15         209  008       16   95.0   78.0
# 16         209  008       17   93.0   79.0
# 17         209  008       18   78.0   78.0
# 18         209  008       20   95.0   80.0
# 19         209  008       21   93.0   78.0
# ✅ CSV saved to: /home/lorena/Documents/PhD/EEEMCal_Analysis/Pedestal_Stability/Data/Pedestals/pedestals_HV_vs_NoHV_FPGA209_210.csv

# %%
# Verify that each JSON has exactly one pedestal per channel (excluding skipped ones)

for (fpga, pb, cond), path in files.items():
    ped = load_pedestals(path)
    print(f"{ped}")
    unique_channels = len(ped)
    unique_values = len(set(ped.keys()))
    print(f"{fpga=} {pb=} {cond=}: {unique_channels} unique channels mapped")

    # sanity check
    if unique_channels != unique_values:
        print("⚠️  Channel index duplication detected!")
    else:
        print("✅  One-to-one mapping confirmed.")

    # quick check of possible duplicates or length mismatch
    if len(ped) != (151 - len(exclude_channels)):
        print(f"⚠️  Expected {151 - len(exclude_channels)} channels, found {len(ped)}")
    else:
        print("✅  Channel count matches expectation.")
    print("-"*50)
# Out:
# {1: 101.0, 2: 96.0, 3: 95.0, 4: 95.0, 5: 97.0, 6: 95.0, 7: 95.0, 8: 95.0, 9: 115.0, 10: 94.0, 11: 107.0, 12: 102.0, 13: 94.0, 14: 97.0, 15: 93.0, 16: 95.0, 17: 93.0, 18: 78.0, 20: 95.0, 21: 93.0, 22: 91.0, 23: 95.0, 24: 93.0, 25: 93.0, 26: 91.0, 27: 92.0, 28: 80.0, 29: 87.0, 30: 92.0, 31: 89.0, 32: 87.0, 33: 91.0, 34: 91.0, 35: 84.0, 36: 91.0, 37: 0.0, 39: 81.0, 40: 79.0, 41: 81.0, 42: 79.0, 43: 84.0, 44: 80.0, 45: 80.0, 46: 82.0, 47: 83.0, 48: 81.0, 49: 83.0, 50: 101.0, 51: 79.0, 52: 85.0, 53: 80.0, 54: 82.0, 55: 81.0, 56: 74.0, 58: 85.0, 59: 81.0, 60: 85.0, 61: 85.0, 62: 86.0, 63: 90.0, 64: 83.0, 65: 91.0, 66: 81.0, 67: 88.0, 68: 86.0, 69: 86.0, 70: 83.0, 71: 85.0, 72: 83.0, 73: 85.0, 74: 87.0, 75: 0.0, 77: 89.0, 78: 90.0, 79: 92.0, 80: 89.0, 81: 89.0, 82: 91.0, 83: 86.0, 84: 86.0, 85: 80.0, 86: 86.0, 87: 91.0, 88: 92.0, 89: 85.0, 90: 111.0, 91: 91.0, 92: 89.0, 93: 89.0, 94: 86.0, 96: 90.0, 97: 88.0, 98: 86.0, 99: 86.0, 100: 85.0, 101: 89.0, 102: 87.0, 103: 73.0, 104: 79.0, 105: 85.0, 106: 88.0, 107: 87.0, 108: 86.0, 109: 86.0, 110: 86.0, 111: 85.0, 112: 84.0, 113: 0.0, 115: 84.0, 116: 80.0, 117: 79.0, 118: 91.0, 119: 86.0, 120: 81.0, 121: 80.0, 122: 79.0, 123: 81.0, 124: 82.0, 125: 82.0, 126: 79.0, 127: 80.0, 128: 83.0, 129: 82.0, 130: 84.0, 131: 83.0, 132: 81.0, 134: 81.0, 135: 84.0, 136: 82.0, 137: 82.0, 138: 84.0, 139: 80.0, 140: 84.0, 141: 85.0, 142: 85.0, 143: 83.0, 144: 84.0, 145: 80.0, 146: 62.0, 147: 81.0, 148: 82.0, 149: 84.0, 150: 73.0, 151: 0.0}
# fpga='209' pb='008' cond='NoHV': 144 unique channels mapped
# ✅  One-to-one mapping confirmed.
# ✅  Channel count matches expectation.
# --------------------------------------------------
# {1: 81.0, 2: 79.0, 3: 79.0, 4: 78.0, 5: 81.0, 6: 79.0, 7: 81.0, 8: 79.0, 9: 118.0, 10: 81.0, 11: 95.0, 12: 87.0, 13: 78.0, 14: 81.0, 15: 80.0, 16: 78.0, 17: 79.0, 18: 78.0, 20: 80.0, 21: 78.0, 22: 77.0, 23: 78.0, 24: 79.0, 25: 79.0, 26: 77.0, 27: 79.0, 28: 79.0, 29: 78.0, 30: 79.0, 31: 81.0, 32: 81.0, 33: 79.0, 34: 79.0, 35: 75.0, 36: 77.0, 37: 0.0, 39: 81.0, 40: 79.0, 41: 83.0, 42: 82.0, 43: 80.0, 44: 77.0, 45: 79.0, 46: 79.0, 47: 83.0, 48: 80.0, 49: 81.0, 50: 98.0, 51: 77.0, 52: 81.0, 53: 81.0, 54: 81.0, 55: 77.0, 56: 72.0, 58: 79.0, 59: 81.0, 60: 81.0, 61: 80.0, 62: 79.0, 63: 79.0, 64: 79.0, 65: 82.0, 66: 79.0, 67: 78.0, 68: 79.0, 69: 78.0, 70: 81.0, 71: 80.0, 72: 82.0, 73: 79.0, 74: 77.0, 75: 0.0, 77: 79.0, 78: 82.0, 79: 79.0, 80: 79.0, 81: 80.0, 82: 83.0, 83: 81.0, 84: 78.0, 85: 83.0, 86: 79.0, 87: 81.0, 88: 80.0, 89: 77.0, 90: 105.0, 91: 81.0, 92: 80.0, 93: 79.0, 94: 86.0, 96: 80.0, 97: 79.0, 98: 79.0, 99: 79.0, 100: 81.0, 101: 83.0, 102: 77.0, 103: 74.0, 104: 79.0, 105: 78.0, 106: 77.0, 107: 79.0, 108: 81.0, 109: 79.0, 110: 79.0, 111: 79.0, 112: 79.0, 113: 0.0, 115: 81.0, 116: 80.0, 117: 79.0, 118: 92.0, 119: 83.0, 120: 78.0, 121: 78.0, 122: 77.0, 123: 83.0, 124: 81.0, 125: 78.0, 126: 77.0, 127: 80.0, 128: 79.0, 129: 82.0, 130: 81.0, 131: 80.0, 132: 80.0, 134: 77.0, 135: 80.0, 136: 80.0, 137: 81.0, 138: 81.0, 139: 79.0, 140: 79.0, 141: 79.0, 142: 85.0, 143: 79.0, 144: 81.0, 145: 79.0, 146: 58.0, 147: 79.0, 148: 77.0, 149: 78.0, 150: 70.0, 151: 0.0}
# fpga='209' pb='008' cond='HV': 144 unique channels mapped
# ✅  One-to-one mapping confirmed.
# ✅  Channel count matches expectation.
# --------------------------------------------------
# {1: 86.0, 2: 89.0, 3: 91.0, 4: 77.0, 5: 62.0, 6: 79.0, 7: 84.0, 8: 75.0, 9: 86.0, 10: 46.0, 11: 73.0, 12: 88.0, 13: 84.0, 14: 92.0, 15: 78.0, 16: 81.0, 17: 87.0, 18: 85.0, 20: 87.0, 21: 71.0, 22: 69.0, 23: 74.0, 24: 81.0, 25: 79.0, 26: 76.0, 27: 53.0, 28: 82.0, 29: 66.0, 30: 43.0, 31: 81.0, 32: 81.0, 33: 24.0, 34: 59.0, 35: 90.0, 36: 71.0, 37: 0.0, 39: 80.0, 40: 51.0, 41: 82.0, 42: 85.0, 43: 85.0, 44: 86.0, 45: 79.0, 46: 47.0, 47: 85.0, 48: 66.0, 49: 85.0, 50: 77.0, 51: 87.0, 52: 81.0, 53: 59.0, 54: 80.0, 55: 80.0, 56: 80.0, 58: 81.0, 59: 83.0, 60: 80.0, 61: 88.0, 62: 83.0, 63: 81.0, 64: 79.0, 65: 87.0, 66: 79.0, 67: 109.0, 68: 82.0, 69: 86.0, 70: 86.0, 71: 78.0, 72: 84.0, 73: 85.0, 74: 65.0, 75: 0.0, 77: 91.0, 78: 57.0, 79: 83.0, 80: 87.0, 81: 106.0, 82: 82.0, 83: 72.0, 84: 78.0, 85: 79.0, 86: 85.0, 87: 85.0, 88: 78.0, 89: 81.0, 90: 41.0, 91: 87.0, 92: 86.0, 93: 89.0, 94: 81.0, 96: 86.0, 97: 95.0, 98: 83.0, 99: 81.0, 100: 79.0, 101: 79.0, 102: 85.0, 103: 82.0, 104: 78.0, 105: 87.0, 106: 84.0, 107: 84.0, 108: 89.0, 109: 83.0, 110: 82.0, 111: 82.0, 112: 67.0, 113: 0.0, 115: 65.0, 116: 64.0, 117: 64.0, 118: 49.0, 119: 81.0, 120: 81.0, 121: 82.0, 122: 79.0, 123: 79.0, 124: 69.0, 125: 85.0, 126: 98.0, 127: 87.0, 128: 85.0, 129: 81.0, 130: 81.0, 131: 91.0, 132: 78.0, 134: 86.0, 135: 85.0, 136: 77.0, 137: 83.0, 138: 89.0, 139: 81.0, 140: 76.0, 141: 86.0, 142: 82.0, 143: 82.0, 144: 81.0, 145: 87.0, 146: 87.0, 147: 84.0, 148: 74.0, 149: 77.0, 150: 85.0, 151: 0.0}
# fpga='210' pb='06' cond='NoHV': 144 unique channels mapped
# ✅  One-to-one mapping confirmed.
# ✅  Channel count matches expectation.
# --------------------------------------------------
# {1: 107.0, 2: 86.0, 3: 87.0, 4: 89.0, 5: 86.0, 6: 104.0, 7: 86.0, 8: 97.0, 9: 121.0, 10: 82.0, 11: 77.0, 12: 89.0, 13: 85.0, 14: 105.0, 15: 86.0, 16: 81.0, 17: 100.0, 18: 81.0, 20: 89.0, 21: 81.0, 22: 90.0, 23: 87.0, 24: 82.0, 25: 88.0, 26: 77.0, 27: 83.0, 28: 79.0, 29: 82.0, 30: 75.0, 31: 81.0, 32: 81.0, 33: 55.0, 34: 83.0, 35: 84.0, 36: 83.0, 37: 0.0, 39: 80.0, 40: 63.0, 41: 77.0, 42: 82.0, 43: 79.0, 44: 82.0, 45: 83.0, 46: 62.0, 47: 80.0, 48: 80.0, 49: 101.0, 50: 83.0, 51: 80.0, 52: 83.0, 53: 68.0, 54: 82.0, 55: 88.0, 56: 80.0, 58: 86.0, 59: 80.0, 60: 80.0, 61: 82.0, 62: 81.0, 63: 80.0, 64: 85.0, 65: 85.0, 66: 88.0, 67: 125.0, 68: 83.0, 69: 81.0, 70: 87.0, 71: 85.0, 72: 83.0, 73: 80.0, 74: 79.0, 75: 0.0, 77: 87.0, 78: 69.0, 79: 82.0, 80: 82.0, 81: 120.0, 82: 85.0, 83: 81.0, 84: 88.0, 85: 80.0, 86: 86.0, 87: 85.0, 88: 92.0, 89: 82.0, 90: 50.0, 91: 87.0, 92: 85.0, 93: 85.0, 94: 83.0, 96: 85.0, 97: 101.0, 98: 90.0, 99: 82.0, 100: 81.0, 101: 83.0, 102: 89.0, 103: 88.0, 104: 79.0, 105: 90.0, 106: 84.0, 107: 88.0, 108: 91.0, 109: 84.0, 110: 83.0, 111: 83.0, 112: 70.0, 113: 0.0, 115: 56.0, 116: 64.0, 117: 61.0, 118: 53.0, 119: 81.0, 120: 82.0, 121: 86.0, 122: 84.0, 123: 77.0, 124: 64.0, 125: 80.0, 126: 90.0, 127: 83.0, 128: 82.0, 129: 82.0, 130: 81.0, 131: 82.0, 132: 83.0, 134: 79.0, 135: 81.0, 136: 85.0, 137: 85.0, 138: 85.0, 139: 82.0, 140: 81.0, 141: 80.0, 142: 79.0, 143: 82.0, 144: 83.0, 145: 88.0, 146: 92.0, 147: 81.0, 148: 79.0, 149: 75.0, 150: 84.0, 151: 0.0}
# fpga='210' pb='06' cond='HV': 144 unique channels mapped
# ✅  One-to-one mapping confirmed.
# ✅  Channel count matches expectation.
# --------------------------------------------------
